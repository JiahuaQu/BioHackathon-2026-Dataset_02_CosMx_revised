# %%
conda activate spatialdata
python -m pip install ipykernel

# %%
python -m ipykernel install --user \
    --name spatialdata \
    --display-name "Python (spatialdata)"

# %% [markdown]
# Installed kernelspec spatialdata in /research/rgs01/home/clusterHome/jqu/.local/share/jupyter/kernels/spatialdata

# %%
jupyter kernelspec list

# %% [markdown]
# Available kernels:
#   python3        /home/jqu/.conda/envs/spatialdata/share/jupyter/kernels/python3
#   metaconga      /research/rgs01/home/clusterHome/jqu/.local/share/jupyter/kernels/metaconga
#   myenv          /research/rgs01/home/clusterHome/jqu/.local/share/jupyter/kernels/myenv
#   spatialdata    /research/rgs01/home/clusterHome/jqu/.local/share/jupyter/kernels/spatialdata

# %%
cat ~/.local/share/jupyter/kernels/spatialdata/kernel.json

# %%
import socket
print(socket.gethostname())
